# %%
###################### Encoded #############################
xml                      .xml

Delta                    .delta   (DE)

Parquet                  .Delta   (DE)

tf record                .

# %%
excel sheet          .xlsx
json                 .json

pdf                  .pdf

# %%
# mbox-shot

#folder_name="C:\Users\shaik"
    
#file_name="mbox-shot"

#extension=".txt"

#<folder_name>\<file_name><.txt>

"C:\\Users\\shaik\\mbox-shot\\.txt"

# %% [markdown]
#  $Textfiles$

# %%
path=r"C:\Users\shaik\Documents\Python Data files used for analysis"
path

# %%
file=open(path)
print(file.read())

# %%
open()


mode='r'  :  read the file
    
mode='w'  :  write the file
    
mode='rb' :  read bytes file

mode='wb' :  write bytes file
    
    
    
    
    -some time data has unusual charecters

# %%
path="C:\\Users\\shaik\\Documents\\Python Data files used for analysis\\chatboat.txt"
file=open(path)
file.read()

# %%
#same by using with keyword

# %% [markdown]
# $with$

# %%
path="C:\\Users\\shaik\\mbox-shot\\.txt"
file=open(path)
file.read()         #session will close

path="C:\\Users\\shaik\\mbox-shot\\.txt"


with open(path) as file:
    print(file.read())

# %%
path="C:\\Users\\shaik\\mbox-shot\\d1.txt"


with open(path) as file:
    print(file.write("python"))

# %%
path="C:\\Users\\shaik\\Documents\\Python Data files used for analysis\\chatboat.txt"
file=open(path)
file.read()

# %%
path="C:\\Users\\shaik\\Documents\\Python Data files used for analysis\\ahmed.txt"
file=open(path,
         mode="w")
file.write("hello how are you ahmed ")

# %%
path='C:\\Users\\shaik\\Documents\\Python Data files used for analysis\\abrar.txt'
file=open(path,
          mode='w')
file.write("iam in doing practice from 10:30am")

# %%
path=r"C:\Users\shaik\Documents\Python Data files used for analysis"

# %%
path=r"C:\Users\shaik\Documents\Python Data files used for analysis"
path="mbox-short.txt"

file=open(path)
count=0
for i in file:
    count=count+1
    
print(count)

# %% [markdown]
# $enumarate$

# %% [markdown]
# $enumerate will provide both index and line$

# %%
path=r'C:\Users\shaik\Documents\Python Data files used for analysis\mbox-short.txt'

file=open(path)
for line in file:
    print(line)

# %%
path=r'C:\Users\shaik\Documents\Python Data files used for analysis\mbox-short.txt'

file=open(path)
for index,_ in enumerate(file):
    print(index)

# %%
path=r'C:\Users\shaik\Documents\Python Data files used for analysis\mbox-short.txt'

file=open(path)
for index,_ in enumerate(file):
    pass

index+1

# %%
for i in range(5):
    pass
i

# %%
path=r'C:\Users\shaik\Documents\Python Data files used for analysis\mbox-short.txt'
file=open(path)
for index,line in enumerate(file):
    print(index,line)
    if index==10:
        break
# Out:
# 0 ï»¿From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# 1 Return-Path: <postmaster@collab.sakaiproject.org>
#
# 2 Received: from murder (mail.umich.edu [141.211.14.90])
#
# 3          by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 4          Sat, 05 Jan 2008 09:14:16 -0500
#
# 5 X-Sieve: CMU Sieve 2.3
#
# 6 Received: from murder ([unix socket])
#
# 7          by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 8          Sat, 05 Jan 2008 09:14:16 -0500
#
# 9 Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 10         by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;

# %%
#ques.5- align all the line

# %%
#6- i want the lines which are start with from

path=r'C:\Users\shaik\Documents\Python Data files used for analysis\mbox-short.txt'
file=open(path)
for line in file:
    if line.startswith("from"):
        print(line)

# %%
path=r'C:\Users\shaik\Documents\Python Data files used for analysis\mbox-short.txt'
file="mbox-short.txt"
list1=[line for line in file if line.startswith("from")]
list1
# Out:
# []

# %%
#q8-
for line in list2:
    priunt(line.split([]))
    
emails_list=[line.split()[1]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 #q8-
# ----> 2 for line in list2:
#       3     priunt(line.split([]))
#       5 emails_list=[line.split()[1]]
#
# NameError: name 'list2' is not defined

# %%
#q9- unique email id
unique_emails=[]
for i in emails_list:
    if i not in email_list:
        unique_email.append(i)
l1
len(l1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 #q9- unique email id
#       2 unique_emails=[]
# ----> 3 for i in emails_list:
#       4     if i not in email_list:
#       5         unique_email.append(i)
#
# NameError: name 'emails_list' is not defined

# %%
="C:\\Users\\shaik\\Documents\\Python Data files used for analysis\\chatboat.txt"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 l1="C:\\Users\\shaik\\Documents\\Python Data files used for analysis\\chatboat.txt"
# ----> 2 l1()
#
# TypeError: 'str' object is not callable

# %%
r"‪C:\Users\shaik\Documents\Python Data files used for analysis\chatboat.txt"
# Out:
# '\u202aC:\\Users\\shaik\\Documents\\Python Data files used for analysis\\chatboat.txt'

# %%
path=r"‪C:\Users\shaik\Documents\Python Data files used for analysis\chatboat.txt"
file= open(path)
file.read()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 2
#       1 path=r"‪C:\Users\shaik\Documents\Python Data files used for analysis\chatboat.txt"
# ----> 2 file= open(path)
#       3 file.read()
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# OSError: [Errno 22] Invalid argument: '\u202aC:\\Users\\shaik\\Documents\\Python Data files used for analysis\\chatboat.txt'

# %%
r"C:\Users\shaik\Documents\Python\chatboat.txt"
# Out:
# 'C:\\Users\\shaik\\Documents\\Python\\chatboat.txt'

# %%
path='chatboat.txt'
file=open(path)
file.read()
# Out:
# 'ï»¿Data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processes, algorithms and systems to extract or extrapolate knowledge and insights from noisy, structured, and unstructured data.[2]\n\n\nData science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3] Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]\n\n\nData science is a "concept to unify statistics, data analysis, informatics, and their related methods" to "understand and analyze actual phenomena" with data.[5] It uses techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, information science, and domain knowledge.[6] However, data science is different from computer science and information science. Turing Award winner
# ...

# %%
metamorphosis clean

# %%
path="metamorphosis clean.txt"
file=open(path)
#file.read()
for i in file:
    print(i)
# Out:
# ï»¿One morning, when Gregor Samsa woke from troubled dreams, he found
#
# himself transformed in his bed into a horrible vermin.  He lay on
#
# his armour-like back, and if he lifted his head a little he could
#
# see his brown belly, slightly domed and divided by arches into stiff
#
# sections.  The bedding was hardly able to cover it and seemed ready
#
# to slide off any moment.  His many legs, pitifully thin compared
#
# with the size of the rest of him, waved about helplessly as he
#
# looked.
#
#
#
#
#
# "What's happened to me?" he thought.  It wasn't a dream.  His room,
#
# a proper human room although a little too small, lay peacefully
#
# between its four familiar walls.  A collection of textile samples
#
# lay spread out on the table - Samsa was a travelling salesman - and
#
# above it there hung a picture that he had recently cut out of an
#
# illustrated magazine and housed in a nice, gilded frame.  It showed
#
# ...

# %%
path='metamorphosis clean.txt'
file=open(path)
file.read()
# Out:
# 'ï»¿One morning, when Gregor Samsa woke from troubled dreams, he found\nhimself transformed in his bed into a horrible vermin.  He lay on\nhis armour-like back, and if he lifted his head a little he could\nsee his brown belly, slightly domed and divided by arches into stiff\nsections.  The bedding was hardly able to cover it and seemed ready\nto slide off any moment.  His many legs, pitifully thin compared\nwith the size of the rest of him, waved about helplessly as he\nlooked.\n\n\n"What\'s happened to me?" he thought.  It wasn\'t a dream.  His room,\na proper human room although a little too small, lay peacefully\nbetween its four familiar walls.  A collection of textile samples\nlay spread out on the table - Samsa was a travelling salesman - and\nabove it there hung a picture that he had recently cut out of an\nillustrated magazine and housed in a nice, gilded frame.  It showed\na lady fitted out with a fur hat and fur boa who sat upright,\nraising a heavy fur muff that covered th
# ...

# %%
path="metamorphosis clean.txt"
file=open(path)
count=0
for i in file:
    count=count+1
print(count)
# Out:
# 2050

# %%
#Q2) Print first 10 lines
path="metamorphosis clean.txt"
file=open(path)
count=0
for i in file:
    print(i)
    count=count+1
    if count==10:
        break
# Out:
# ï»¿One morning, when Gregor Samsa woke from troubled dreams, he found
#
# himself transformed in his bed into a horrible vermin.  He lay on
#
# his armour-like back, and if he lifted his head a little he could
#
# see his brown belly, slightly domed and divided by arches into stiff
#
# sections.  The bedding was hardly able to cover it and seemed ready
#
# to slide off any moment.  His many legs, pitifully thin compared
#
# with the size of the rest of him, waved about helplessly as he
#
# looked.

# %%
path="metamorphosis clean.txt"
file=open(path)
for index,line in enumerate(file):
    print(index,line)
# Out:
# 0 ï»¿One morning, when Gregor Samsa woke from troubled dreams, he found
#
# 1 himself transformed in his bed into a horrible vermin.  He lay on
#
# 2 his armour-like back, and if he lifted his head a little he could
#
# 3 see his brown belly, slightly domed and divided by arches into stiff
#
# 4 sections.  The bedding was hardly able to cover it and seemed ready
#
# 5 to slide off any moment.  His many legs, pitifully thin compared
#
# 6 with the size of the rest of him, waved about helplessly as he
#
# 7 looked.
#
# 8
#
# 9
#
# 10 "What's happened to me?" he thought.  It wasn't a dream.  His room,
#
# 11 a proper human room although a little too small, lay peacefully
#
# 12 between its four familiar walls.  A collection of textile samples
#
# 13 lay spread out on the table - Samsa was a travelling salesman - and
#
# 14 above it there hung a picture that he had recently cut out of an
#
# 15 illustrated magazine and housed in a nice, gilded frame.  It showed
#
# ...

# %%
path="metamorphosis clean.txt"
file=open(path)
for index,_ in enumerate(file):
    pass
index+1
# Out:
# 2050

# %%
path="metamorphosis clean.txt"
file = open(path)
for index,line in enumerate(file):
    print(index,line)
    if index==10:break
# Out:
# 0 ï»¿One morning, when Gregor Samsa woke from troubled dreams, he found
#
# 1 himself transformed in his bed into a horrible vermin.  He lay on
#
# 2 his armour-like back, and if he lifted his head a little he could
#
# 3 see his brown belly, slightly domed and divided by arches into stiff
#
# 4 sections.  The bedding was hardly able to cover it and seemed ready
#
# 5 to slide off any moment.  His many legs, pitifully thin compared
#
# 6 with the size of the rest of him, waved about helplessly as he
#
# 7 looked.
#
# 8
#
# 9
#
# 10 "What's happened to me?" he thought.  It wasn't a dream.  His room,

# %% [markdown]
# # 17thsession_19-02

# %%
path=''

# %%
s1='santhanam, Jayendhran <jayendhran.ms@accenture.com>'
i1=s1.index(',')
name=s1[0:i1]
name
i2=s1.index('<')
sec=s1[i1+1:i2]
i3=s1.index('>')
com=s1[i2+1:i3]
name,sec,com
# Out:
# ('santhanam', ' Jayendhran ', 'jayendhran.ms@accenture.com')

# %%
s1='santhanam, Jayendhran <jayendhran.ms@accenture.com>'
s2='jayendhran.ms@accenture.com'
#i1=name
#i2=sec
#i3=com
#i4=acc

i1=s1.index(',')
i2=s1.index('<')
i3=s1.index('>')
i6=s2.index('.com')

name=s1[0:i1]
sec=s1[i1+1:i2]
email=s1[i2+1:i3]
com=s2[i5+1:i6]


name,sec,email,com
# Out:
# ('santhanam', ' Jayendhran ', 'jayendhran.ms@accenture.com', 'accenture')

# %%
s2='jayendhran.ms@accenture.com'
i4=s2.index('.')
com=s2[0:i4]
com
i5=s2.index('@')
com=s2[i4+1:i5]

com
i6=s2.index('.com')
com=s2[i5+1:i6]
com
# Out:
# 'accenture'

# %%
i6=s2.index('.com')
cmp=s2[i5+1:i6]
cmp
# Out:
# 'accenture'
